# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Masters AUA/Spring 2022/Machine Learning/training
# Out:
# /content/drive/MyDrive/Masters AUA/Spring 2022/Machine Learning/training

# %%
import pandas as pd
import numpy as np

import plotly.express as px

# %%
imdb_df = pd.read_csv('data/imdb_encoded.csv')

# %%
imdb_df.shape
# Out:
# (183967, 46)

# %%
imdb_df.head()
# Out:
#    actor1  actor2  actor3  actor4  director_enc  action  adult  adventure  \
# 0   37241   68568   10147   59050         33767       0      0          0
# 1   63173   22342   29027   25837         23232       0      0          0
# 2   25854   72711   46756   13293         50165       0      0          0
# 3   65473   74085   15914   12858         22254       0      0          0
# 4   32322   21601   43406   69447          6356       0      0          0
#
#    animation  biography  ...  duration  imdb_rating    votes  release_start  \
# 0          0          0  ...      87.0          7.6  13192.0         1950.0
# 1          0          0  ...      81.0          6.3    919.0         1950.0
# 2          0          0  ...      98.0          6.7   4206.0         1950.0
# 3          0          0  ...      83.0          5.6    480.0         1950.0
# 4          0          0  ...      84.0          6.8   2113.0         1950.0
#
#    release_month  tv_series           title  \
# 0              1          0       Gun Crazy
# 1              1          0     The Nevadan
# 2              1          0       Whirlpool
# 3              1          0  The Sundowners
# 4              1          0   The Blue Lamp
#
#                                             synopsis          director  \
# 0  Two disturbed young people release their fasci...   Joseph H. Lewis
# 1  A mysterious stranger crosses paths with an ou...    Gordon Douglas
# 2  A woman suffering from kleptomania is hypnotiz...    Otto Preminger
# 3  Brother is pitted against brother in this tale...  George Templeton
# 4  The daily routine of two London Policemen is i...     Basil Dearden
#
#                                               actors
# 0  ['John Dall', 'Peggy Cummins', 'Berry Kroeger'...
# 1  ['Randolph Scott', 'Dorothy Malone', 'Forrest ...
# 2  ['Gene Tierney', 'Richard Conte', 'José Ferrer...
# 3  ['Robert Preston', 'Robert Sterling', 'Chill W...
# 4  ['Jack Warner', 'Dirk Bogarde', 'Jimmy Hanley'...
#
# [5 rows x 46 columns]

# %%
imdb_df.columns
# Out:
# Index(['actor1', 'actor2', 'actor3', 'actor4', 'director_enc', 'action',
#        'adult', 'adventure', 'animation', 'biography', 'comedy', 'crime',
#        'documentary', 'drama', 'family', 'fantasy', 'film-noir', 'game-show',
#        'history', 'horror', 'music', 'musical', 'mystery', 'news',
#        'reality-tv', 'romance', 'sci-fi', 'short', 'sport', 'talk-show',
#        'thriller', 'unknown', 'war', 'western', 'link', 'genre', 'duration',
#        'imdb_rating', 'votes', 'release_start', 'release_month', 'tv_series',
#        'title', 'synopsis', 'director', 'actors'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Topic modeling

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.10.0-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 2.9 MB/s
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (5.5.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.21.6)
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (3.13)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.0.2)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 4.3 MB/s
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 6.0 MB/s
# Collecting hdbscan>=0.8.28
#   Downloading hdbscan-0.8.28.tar.gz (5.2 MB)
#      |████████████████████████████████| 5.2 MB 32.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (4.64.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic) (1.4.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic) (0.29.28)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.19.1-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 32.4 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.12.0+cu113)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 34.7 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.2 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (4.2.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (4.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2019.12.20)
# Collecting pyyaml<6.0
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 38.4 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 39.0 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.8)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic) (0.51.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.7.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 40.8 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.34.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2330827 sha256=5c2c1443d7e16818898c815d30ea719e99b10db9fd9c9a044464fd5436b4da34
#   Stored in directory: /root/.cache/pip/wheels/6e/7a/5e/259ccc841c085fc41b99ef4a71e896b62f5161f2bc8a14c97a
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=d1b9f0c38e58e1ca2bdab800cbfb83d7978a2ff2c9b162caaa9fc20316d9e8d7
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=2c056c2e7680175e427b8891ab31f51d6e160174426aa26a33efd2029f3a4fd9
#   Stored in directory: /root/.cache/pip/wheels/b3/52/a5/1fd9e3e76a7ab34f134c07469cd6f16e27ef3a37aeff1fe821
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.7-py3-none-any.whl size=54286 sha256=c83951c7df005cba3f362b5c73d6cddb9ec7937b083cd0869767859faca123e9
#   Stored in directory: /root/.cache/pip/wheels/7f/2a/f8/7bd5dcec71bd5c669f6f574db3113513696b98f3f9b51f496c
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, pynndescent, umap-learn, sentence-transformers, hdbscan, bertopic
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed bertopic-0.10.0 hdbscan-0.8.28 huggingface-hub-0.6.0 pynndescent-0.5.7 pyyaml-5.4.1 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.19.1 umap-learn-0.5.3

# %%
import re
import nltk
from nltk.corpus import stopwords

import gensim
from gensim.utils import simple_preprocess

from bertopic import BERTopic

# %%
# deleting rows with no synopsis
imdb_df = imdb_df[imdb_df['synopsis'] != 'Add a Plot'].dropna(subset=['synopsis']).reset_index(drop=True)

# %%
imdb_df.shape
# Out:
# (161602, 46)

# %%
# Removing punctuation
imdb_df['synopsis'] = imdb_df['synopsis'].map(lambda x: re.sub('[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]', '', x))
# Converting the text to lowercase
imdb_df['synopsis'] = imdb_df['synopsis'].map(lambda x: x.lower())
# Removing 'see full summary'
imdb_df['synopsis'] = imdb_df['synopsis'].map(lambda x: re.sub('see full summary\xa0»', '', x))
# Deleting unnecessary spaces
imdb_df['synopsis'] = imdb_df['synopsis'].str.strip()

# %%
# Lemmatization
nltk.download('wordnet')
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

imdb_df['synopsis_lemmatized'] = imdb_df['synopsis'].apply(lemmatize_text)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
# Removing stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) 
             if word not in stop_words] for doc in texts]
             
data = imdb_df['synopsis_lemmatized'].values.tolist()
data_words = list(sent_to_words(data))
# remove stop words
data_words = remove_stopwords(data_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## BERTopic

# %%
model = BERTopic(min_topic_size=50, n_gram_range=(1,3), verbose=True)

# %%
docs = data_words
docs = np.array([(" ").join(i) for i in docs])
# topics = model.fit(docs)

# %%
labels, probs = model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/5051 [00:00<?, ?it/s]
# 2022-05-14 10:51:24,090 - BERTopic - Transformed documents to Embeddings
# 2022-05-14 10:56:05,413 - BERTopic - Reduced dimensionality
# 2022-05-14 10:56:36,476 - BERTopic - Clustered reduced embeddings

# %%
imdb_df['topic'] = labels

# %%
# import pickle
# filename = 'topic_modeling_model.sav'
# pickle.dump(model, open(filename, 'wb'))

# %%
model.get_topic_freq()
# Out:
#      Topic  Count
# 0       -1  95882
# 1        0   4835
# 2        1   4671
# 3        2   3811
# 4        3   3112
# ..     ...    ...
# 137    136     53
# 138    137     53
# 139    138     52
# 140    139     51
# 141    140     50
#
# [142 rows x 2 columns]

# %%
imdb_df.to_csv('data/imdb_encoded_with_topics.csv', index=False)

# %%
model.visualize_barchart(top_n_topics=12)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2421f6d2-3308-4ac6-ab83-f4be73d45d24" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2421f6d2-3308-4ac6-ab83-f4be73d45d24")) {                    Plotly.newPlot(                        "2421f6d2-3308-4ac6-ab83-f4be73d45d24",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.006887760696058996,0.006933711579825634,0.007295119591940552,0.007625766318389949,0.007790591542526943],"y":["kong  ","japan  ","japanese  ","hong  ","martial  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.010234795853539818,0.01073969782667212,0.014768686115035418,0.016212725936631863,0.01775310735224777],"y":["killer  ","cop  ","murder  ","police  ","detective  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.004428633233120672,0.004955025313637621,0.005359675099975776,0.005502936105858148,0.006395988048831524],"y":["france  ","spanish  ","de  ","spain  ","paris  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.010327629514653094,0.011519959217608663,0.011573751686750625,0.012187204801306988,0.023770566952252607],"y":["actor  ","director  ","documentary  ","movie  ","film  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.027287402113519026,0.03436505865906276,0.057524508906966414,0.06692037265686641,0.07296507731576286],"y":["recorded  ","album  ","music  ","music video  ","video  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.011572262647158108,0.01582902442351959,0.018672437887894355,0.024739388514361492,0.025695180410711033],"y":["standup  ","sketch  ","comedian  ","show  ","comedy  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.007666576986233668,0.0076834768222726404,0.008437745466318465,0.008511354375935417,0.009424414139952817],"y":["wealthy  ","lifestyle  ","marry  ","son  ","love  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.012452257940321365,0.013388570452446385,0.013752638018336864,0.017567680645447337,0.023273542769707025],"y":["singer  ","concert  ","music  ","rock  ","band  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.010010819565185722,0.010454003616033498,0.015546960575962146,0.016991859924606022,0.017202097644417404],"y":["evil  ","fairy  ","princess  ","king  ","prince  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.010757690655792436,0.011231499521348026,0.011365165023402079,0.011779899869083316,0.018904728987456383],"y":["relationship  ","husband  ","wedding  ","married  ","couple  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.008874674188341376,0.01289372424376083,0.013451316450579067,0.016499759147377984,0.01700273435515793],"y":["ransom  ","son  ","father  ","daughter  ","kidnapped  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.011845610135356859,0.013445806285360786,0.014520392556089954,0.01848392028359436,0.024501107527925274],"y":["faith  ","god  ","church  ","jesus  ","priest  "],"type":"bar","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size ...

# %%
model.embedding_model

# %%
model.find_topics('computer')
# Out:
# ([115, 67, 106, 83, 26],
#  [0.7771494604087915,
#   0.637647628800309,
#   0.6227392594915524,
#   0.5440665893491932,
#   0.5284670549243317])

# %%
model.save("my_model_without_embedding", save_embedding_model=False)

# %%
# import pickle
# filename = 'topic_modeling_model.sav'
# pickle.dump(model, open(filename, 'wb'))

# %%
model.topic_names[0]
# Out:
# '0_martial_hong_japanese_japan'

# %%
imdb_df[imdb_df.topic == 0]
# Out:
#         actor1  actor2  actor3  actor4  director_enc  action  adult  \
# 50       67235   79751   25033   29984         59942       0      0
# 84       30440   40313   97157   32290         26035       0      0
# 135      81795   92766   57622   48306         39945       0      0
# 248      80936   23432   71085    1326         63750       0      0
# 570      76848   53845   61887   78635          1103       0      0
# ...        ...     ...     ...     ...           ...     ...    ...
# 161524   40415   33805   89444   87466         26836       1      0
# 161540   47710   93092   99348   87466         69620       0      0
# 161562   43515   73271   83096   87466         49360       0      0
# 161578   68175   72405   26129   71865         26759       0      0
# 161592   48543   70204   93426   77661         48290       0      0
#
#         adventure  animation  biography  ...     votes  release_start  \
# 50              0          0          0  ...      47.0         1950.0
# 84              0          0          0  ...      95.0         1949.0
# 135             0          0          0  ...      19.0         1949.0
# 248             0          0          0  ...     168.0         1950.0
# 570             0          0          0  ...  165215.0         1950.0
# ...           ...        ...        ...  ...       ...            ...
# 161524          1          1          0  ...      89.0         2022.0
# 161540          0          0          0  ...      74.0         2022.0
# 161562          0          1          0  ...      32.0         2022.0
# 161578          0          0          0  ...      10.0         2022.0
# 161592          0          0          0  ...      72.0         2022.0
#
#         release_month  tv_series                              title  \
# 50                  1          0                  Akatsuki no dasso
# 84                  1          0                    Ai le zhongnian
# 135                 1          0                        Li ren xing
# 248                 3          0                    Mata au hi made
# 570                 8          0                           Rashômon
# ...               ...        ...                                ...
# 161524              4          0       Shokei Shoujo no Virgin Road
# 161540              4          0                   Qie Shi Tian Xia
# 161562              4          0                            Deaimon
# 161578              4          0  DJS the Movie: Biarkan Aku Menari
# 161592              4          0                  Gajab Thai Gayo !
#
#                                                  synopsis  \
# 50      mikami a japanese soldier serving in china is ...
# 84      in precommunism era of china a widowed man mus...
# 135     three women in japaneseoccupied shanghai 1941 ...
# 248     the hero saburo okada eiji is obstructed by a ...
# 570     the rape of a bride and the murder of her samu...
# ...                                                   ...
# 161524  the lost ones are wanderers who come here from...
# 161540  the story of the feng lan xi and feng xi yun j...
# 161562  nagomu irino returns to his kyoto home for the...
# 161578  in wulans life she only wanted to be a dancer ...
# 161592  sheth kapurchand mangaldas vidyalaya is one of...
#
#                     director  \
# 50        Senkichi Taniguchi
# 84                   Hu Sang
# 135              Liting Chen
# 248             Tadashi Imai
# 570           Akira Kurosawa
# ...                      ...
# 161524            Iori Saeki
# 161540             Yang Yang
# 161562    Nobunaga Shimazaki
# 161578  Indrayanto Kurniawan
# 161592          Neeraj Joshi
#
#                                                    actors  \
# 50      ['Ryô Ikebe', 'Shirley Yamaguchi', 'Eitarô Oza...
# 84      ['Hui Shi', 'Jiachen Zhu', 'Yang Shen', 'Huanq...
# 135     ['Zhongshi Gao', 'Zongying Huang', 'Ma Lan', '...
# 248     ['Yoshiko Kuga', 'Eiji Okada', 'Osamu Takizawa...
# 570     ['Toshirô Mifune', 'Machiko Kyô', 'Masayuki Mo...
# ...                                                   ...
# 161524  ['Kahara Moe', 'Hisako Kanemoto', 'Tamie Kubota']
# 161540                                      ['Lusi Zhao']
# 161562   ['Kozue Yuuki', 'Rikiya Koyama', 'Sayaka Ôhara']
# 161578  ['Sandrinna Michelle', 'Rey Bong', 'Emiliano F...
# 161592  ['Malhar Thakar', 'Pooja Jhaveri', 'Ujjwal Cho...
#
#                                       synopsis_lemmatized  topic
# 50      [mikami, a, japanese, soldier, serving, in, ch...      0
# 84      [in, precommunism, era, of, china, a, widowed,...      0
# 135     [three, woman, in, japaneseoccupied, shanghai,...      0
# 248     [the, hero, saburo, okada, eiji, is, obstructe...      0
# 570     [the, rape, of, a, bride, and, the, murder, of...      0
# ...                                                   ...    ...
# 161524  [the, lost, one, are, wanderer, who, come, her...      0
# 161540  [the, story, of, the, feng, lan, xi, and, feng...      0
# 161562  [nagomu, irino, return, to, his, kyoto, home, ...      0
# 161578  [in, wulans, life, she, only, wanted, to, be, ...      0
# 161592  [sheth, kapurchand, mangaldas, vidyalaya, is, ...      0
#
# [4835 rows x 48 columns]

# %%
imdb_df.columns
# Out:
# Index(['actor1', 'actor2', 'actor3', 'actor4', 'director_enc', 'action',
#        'adult', 'adventure', 'animation', 'biography', 'comedy', 'crime',
#        'documentary', 'drama', 'family', 'fantasy', 'film-noir', 'game-show',
#        'history', 'horror', 'music', 'musical', 'mystery', 'news',
#        'reality-tv', 'romance', 'sci-fi', 'short', 'sport', 'talk-show',
#        'thriller', 'unknown', 'war', 'western', 'link', 'genre', 'duration',
#        'imdb_rating', 'votes', 'release_start', 'release_month', 'tv_series',
#        'title', 'synopsis', 'director', 'actors', 'synopsis_lemmatized',
#        'topic'],
#       dtype='object')
